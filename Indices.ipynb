# %%
import matplotlib.pyplot as plt
import numpy as np


Data = ["P1","P2", "P3","P4","P5","P6","P7","P8","P9","P10"]
NDVI2015 = [-0.019199889, 0.291690588, 0.259104401, 0.289544791, 0.313919008, 0.411967158, 0.356048584, 0.269513875, 0.341978639, 0.253944159, 0.313758194, 0.235404328, 0.316935629, 0.309362769, 0.250496387, 0.290020943, 0.176016256, 0.214390248, 0.230199203, 0.374880165
]

-0.019199889, 0.291690588, 0.259104401, 0.289544791, 0.313919008, 0.411967158, 0.356048584, 0.269513875, 0.341978639, 0.253944159, 0.313758194, 0.235404328, 0.316935629, 0.309362769, 0.250496387, 0.290020943, 0.176016256, 0.214390248, 0.230199203, 0.374880165

NDVI2025 = [-0.041139241, 0.179796457, 0.223578542, 0.280710787, 0.25124678, 0.451486439, 0.418114781, 0.144355968, 0.252581984, 0.289515764, 0.275177777, 0.275860399, 0.342793792, 0.208250016, 0.223024815, 0.151252374, 0.158512563, 0.172969505, 0.134839326, 0.36387068
]


NDMI2015 =[0.074745618, 0.044577114, -0.000431507, 0.096384265, 0.056223065, 0.26614064, 0.192137927, -0.00859074, 0.151233166, 0.028688099, 0.038580246, 0.064949803, 0.126331016, 0.083109744, 0.030164707, 0.072724581, -0.055809401, 0.028016467, 0.006634327, 0.219207451
]
NDMI2025 = [0.069232062, -0.083067507, -0.086598121, 0.087707788, 0.010134666, 0.299039304, 0.249248415, -0.114298232, 0.056764737, 0.097692922, 0.013938199, 0.08988487, 0.198021755, -0.020222576, -0.011638447, -0.10305018, -0.069095843, -0.009740259, -0.046730265, 0.19478789
]


NDWI2015 = [0.132611349, -0.242762849, -0.257929891, -0.182625592, -0.254437357, -0.108016521, -0.124743946, -0.277922273, -0.171681076, -0.233487144, -0.263584882, -0.13391912, -0.163496226, -0.221907288, -0.20474413, -0.194922939, -0.259588063, -0.173405379, -0.218231916, -0.119936377
]

NDWI2025 = [0.160439566, -0.295565158, -0.331545681, -0.184887081, -0.251865506, -0.117774881, -0.134813264, -0.311649024, -0.198277056, -0.189089745, -0.26913476, -0.151373282, -0.103609733, -0.260102898, -0.236516729, -0.288977474, -0.264847517, -0.196975946, -0.209038645, -0.130326331
]

plt.figure(figsize=(15, 7))

plt.subplot(3,1,1)
plt.plot(NDVI2015,marker = "o", label = "NDVI 2015", color = "blue")
plt.plot( NDVI2025,marker = "o", label = "NDVI 2025", color = "green")
plt.title("Comparison of different indices such as; NDVI, NDWI, NDMI of 2015 and 2025. \nKayonza District of Rwanda.")
plt.ylabel("NDVI Values")
plt.xlabel("Points Values")
plt.grid(True, linestyle = "--", alpha = 0.7)
plt.legend()


plt.subplot(3,1,2)
plt.plot(NDMI2015,marker = "o", label = "NDMI 2015", color = "cyan")
plt.plot( NDMI2025,marker = "o", label = "NDMI 2025", color = "magenta")
plt.ylabel("NDMI Values")
plt.xlabel("Points Values")
plt.grid(True, linestyle = "--", alpha = 0.7)
plt.legend()


plt.subplot(3,1,3)
plt.plot(NDWI2015,marker = "o", label = "NDWI 2015", color = "black")
plt.plot( NDWI2025,marker = "o", label = "NDWI 2025", color = "red")
plt.ylabel("NDWI Values")
plt.xlabel("Points Values")
plt.grid(True, linestyle = "--", alpha = 0.7)
plt.legend()


plt.tight_layout()
plt.show()
